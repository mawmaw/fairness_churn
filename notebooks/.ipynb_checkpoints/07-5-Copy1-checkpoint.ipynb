# %%
import datetime
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
# !pip install lightgbm
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import learning_curve
# from yellowbrick.model_selection import learning_curve


# SMOTE and Near Miss
from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import NearMiss, RandomUnderSampler

# !pip install 'aif360[AdversarialDebiasing]'
from aif360.datasets import StandardDataset
from aif360.metrics import BinaryLabelDatasetMetric, ClassificationMetric
from aif360.explainers import MetricTextExplainer, MetricJSONExplainer
# from aif360.algorithms.preprocessing import Reweighing

plt.style.use("fivethirtyeight")

from IPython.display import display, HTML

import warnings
print('Ok')
# Out:
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-03-06 11:25:29.494032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-06 11:25:29.494063: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Ok

# %%
def logTime(msg):
    print('{} \t{}'.format(msg, datetime.datetime.now()))
logTime('Process start')
# Out:
# Process start 	2022-03-06 11:25:30.452428

# %%
# %%time
#data = pd.read_csv("""..\data\interim\data_100000-5percent.csv""")
data = pd.read_csv("""../data/interim/data_100000-5percent.csv""")
data2 = data.drop(['customer'], axis=1)
# data2 = data2.drop(['tenure'], axis=1)
# data2 = data2.drop(['comeback_product'], axis=1)

data2['gender'] = data2['gender'].astype(int)
# data2['churn'] = data2['churn'].astype(object)
data2['is_senior'] = data2['is_senior'].astype(int)
data2['contract_period'] = data2['contract_period'].astype(object)

numerical = data2.select_dtypes(['number']).columns
print(f'Numerical: {numerical}\n')

categorical = data2.columns.difference(numerical)

data2[categorical] = data2[categorical].astype('object')
print(f'Categorical: {categorical}')

data2 = pd.get_dummies(data2)

X_original = data2.drop('churn', axis=1)
y_original = data2['churn']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
print(len(data2.keys()))
data2.keys()
# Out:
# Numerical: Index(['age', 'gender', 'hsbb_area', 'speed', 'price_start', 'complain_count',
#        'churn', 'median_outstanding', 'technical_problem_count', 'is_senior',
#        'avg_download', 'avg_upload', 'avg_voice_usage'],
#       dtype='object')
#
# Categorical: Index(['contract_period', 'race', 't_location'], dtype='object')
# 46
# CPU times: user 150 ms, sys: 0 ns, total: 150 ms
# Wall time: 179 ms
# In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
# Index(['age', 'gender', 'hsbb_area', 'speed', 'price_start', 'complain_count',
#        'churn', 'median_outstanding', 'technical_problem_count', 'is_senior',
#        'avg_download', 'avg_upload', 'avg_voice_usage', 'race_B', 'race_C',
#        'race_I', 'race_M', 'race_O', 't_location_Zone-AJP',
#        't_location_Zone-AKM', 't_location_Zone-BAL', 't_location_Zone-BKK',
#        't_location_Zone-BLS', 't_location_Zone-CSM', 't_location_Zone-GCK',
#        't_location_Zone-GHP', 't_location_Zone-GPP', 't_location_Zone-GRT',
#        't_location_Zone-IRM', 't_location_Zone-KDS', 't_location_Zone-KRP',
#        't_location_Zone-NSN', 't_location_Zone-PBP', 't_location_Zone-PDK',
#        't_location_Zone-RLK', 't_location_Zone-SRJ', 't_location_Zone-TLK',
#        't_location_Zone-TLS', 't_location_Zone-UBS', 't_location_Zone-URJ',
#        't_location_Zone-UWT', 'contract_period_1', 'contract_period_12',
#        'contract_period_18', 'contract_period_24', 'contract_period_36'],
#       dtype='object')

# %%
models = []
models.append(('Random Forest', RandomForestClassifier()))
models.append(("LightGBM", LGBMClassifier()))
models.append(('Gradient Boosting', GradientBoostingClassifier()))
models.append(('Logistic Reg.', LogisticRegression(max_iter=1000)))

models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False)))
models.append(('DecisionTreeClassifier', DecisionTreeClassifier()))

methods = ['original', 'adasyn', 'smote', 'rus', 'ros']

# %%
# AIF360 Dataset Preparation

all_labels = ['age', 'gender', 'hsbb_area', 'speed', 'price_start', 'complain_count',
       'churn', 'median_outstanding', 'technical_problem_count', 'is_senior',
       'avg_download', 'avg_upload', 'avg_voice_usage', 'race_B', 'race_C',
       'race_I', 'race_M', 'race_O', 't_location_Zone-AJP',
       't_location_Zone-AKM', 't_location_Zone-BAL', 't_location_Zone-BKK',
       't_location_Zone-BLS', 't_location_Zone-CSM', 't_location_Zone-GCK',
       't_location_Zone-GHP', 't_location_Zone-GPP', 't_location_Zone-GRT',
       't_location_Zone-IRM', 't_location_Zone-KDS', 't_location_Zone-KRP',
       't_location_Zone-NSN', 't_location_Zone-PBP', 't_location_Zone-PDK',
       't_location_Zone-RLK', 't_location_Zone-SRJ', 't_location_Zone-TLK',
       't_location_Zone-TLS', 't_location_Zone-UBS', 't_location_Zone-URJ',
       't_location_Zone-UWT', 
        # 'contract_period_1', 
        'contract_period_12',
       'contract_period_18', 'contract_period_24', 'contract_period_36']

features = ['age', 'gender', 'hsbb_area', 'speed', 'price_start', 'complain_count',
       'churn', 'median_outstanding', 'technical_problem_count', 'is_senior',
       'avg_download', 'avg_upload', 'avg_voice_usage', 'race_B', 'race_C',
       'race_I', 'race_M', 'race_O', 't_location_Zone-AJP',
       't_location_Zone-AKM', 't_location_Zone-BAL', 't_location_Zone-BKK',
       't_location_Zone-BLS', 't_location_Zone-CSM', 't_location_Zone-GCK',
       't_location_Zone-GHP', 't_location_Zone-GPP', 't_location_Zone-GRT',
       't_location_Zone-IRM', 't_location_Zone-KDS', 't_location_Zone-KRP',
       't_location_Zone-NSN', 't_location_Zone-PBP', 't_location_Zone-PDK',
       't_location_Zone-RLK', 't_location_Zone-SRJ', 't_location_Zone-TLK',
       't_location_Zone-TLS', 't_location_Zone-UBS', 't_location_Zone-URJ',
       't_location_Zone-UWT', 
        # 'contract_period_1', 
        'contract_period_12',
       'contract_period_18', 'contract_period_24', 'contract_period_36']


class TMDataset(StandardDataset):
    def __init__(self, 
             label_name='churn',
             favorable_classes=[1.0],
                 
             protected_attribute_names=[
                'gender', 
#                 'is_senior',
#                 'race_O',
             ],
    
             privileged_classes=[
                [1.0,], 
#                 [0.0,],
#                 [0.0,],
             ],
                 
             instance_weights_name=None,
             categorical_features=[],
             features_to_keep=features, 
             features_to_drop=[],
             custom_preprocessing=None,
             metadata=None,
             csv_file_name='',
             data_frame=None,
    ):
        
        if data_frame is not None:
            aif_df = data_frame
        else:
            aif_df = pd.read_csv(csv_file_name)
        
        #df.reset_index(drop=True, inplace=True)
        # Preprocessing
        
        super().__init__(
            df=aif_df, label_name=label_name,
            favorable_classes=favorable_classes,
            protected_attribute_names=protected_attribute_names,
            privileged_classes=privileged_classes,
            instance_weights_name=instance_weights_name,
            categorical_features=categorical_features,
            features_to_keep=features_to_keep,
            features_to_drop=features_to_drop,
            custom_preprocessing=custom_preprocessing, 
            metadata=metadata,
     
        )

# %%
def make_sampling(method_name, X, y):
    if method_name == 'original':
        return (X, y)
    elif method_name == 'adasyn':
        adasyn = ADASYN(sampling_strategy='minority', random_state=420, n_neighbors=5)
        return adasyn.fit_resample(X, y)
    elif method_name == 'smote':
        os = SMOTE(random_state=41)
        return os.fit_resample(X, y)
    elif method_name == 'ros':
        random_over_sampler = RandomOverSampler(random_state=42)
        return random_over_sampler.fit_resample(X, y)
    elif method_name == 'rus':
        random_under_sampler = RandomUnderSampler(random_state=42)
        return random_under_sampler.fit_resample(X, y)
    else:
        print('UNKNOWN METHOD !!')

# %%
def create_learningcurve(classfier, X, y):
    # classfier = model
    # print('Process started at {}'.format(datetime.datetime.now())) 
    train_sizes_initial = np.linspace(0.01, 1.0, 50)
    train_sizes, train_scores, test_scores = learning_curve(
        classfier, X, y, cv=10, scoring='accuracy', 
        n_jobs=-1, train_sizes=train_sizes_initial)
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)

    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    plt.subplots(1, figsize=(10,10))
    plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
    plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

    plt.title("Learning Curve")
    plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
    plt.tight_layout()

    plt.pause(0.05)
    # print('Process end at {}'.format(datetime.datetime.now())) 
    # print(learning_curve(model, X, y, cv=30, scoring='accuracy'))

    # end plot

# %%
def runModels(model_index, method_index):
    name, model = models[model_index - 1]
    method = methods[method_index - 1]
    display(HTML(f'<h2>{model_index}.{method_index} {name} - {method} </h2>'))
    time.sleep(1)
    
    time.sleep(1)
    method_index += 1
    # display(HTML(f'<h3> {model_index}.{method_index} {method} </h3>'))
    X, y = make_sampling(method, X_original, y_original)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
    score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')

    print('Charn values Original')
    print(y.value_counts())
    print('Total data: {}'.format(y.count()))

    print('\nCharn values Train')
    print(y_train.value_counts())
    print('Total data: {}'.format(y_train.count()))

    print('\nCharn values Test')
    print(y_test.value_counts())
    print('Total data: {}'.format(y_test.count()))

    print("\n")
    print("*_" * 20)
    print(f"Mean scores : {score.mean()}")

    model.fit(X_train, y_train)

    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    print(metrics.classification_report(y_pred_test, y_test))

    # Learning curve start
    print('Creating Learning curve for {} - {}'.format(name, method))
    # %time create_learningcurve(model, X, y)

    pred_df = X_test.copy()
    pred_df['churn'] = y_pred_test

    print('\n Gender Count in predited value with X_test set')
    print('# ' * 10)
    print(pred_df.gender.value_counts())
    p_df = pred_df[['churn', 'gender']]
    print('\n')
    p_df.insert(2, 'counter', 1)
    print(p_df.groupby(['churn','gender',]).sum())
    print('# ' * 10)

    print(metrics.confusion_matrix(y_test, y_pred_test))
    metrics.plot_confusion_matrix(model, X_test, y_test)
    plt.show()

    y_proba = model.predict_proba(X_test)[:, 1]
    roc_auc_score = metrics.roc_auc_score(y_test, y_proba)
    print('\n\n')
    print(f'ROC AUC Score {roc_auc_score}')


    # Additional matrix
    df_pred = X_test
    df_pred.reset_index(drop=True, inplace=True)

    pred = pd.Series(y_pred_test)
    df_pred = df_pred.assign(churn=pred)

    # df_pred = df_pred.assign(churn=y_test)

    aif_df = TMDataset(data_frame=df_pred)
    aif_df_labeled = aif_df.copy()
    aif_df_labeled.labels = y_pred_test

    result_tbl_cols = [
        'Attribute',
        'Mean difference', 
        'Positive Outcome',
        'Negative', 
        'Differences', 
        'Disparate impact', 
        'Consistency',
        'Statistical parity dif',
    ]

    result_rows = []
    for p_attribute in aif_df.protected_attribute_names:
        result_row = []
        privileged_groups = [{p_attribute: 1}]
        print(' * ' * 10)
        print(privileged_groups)
        unprivileged_groups = [{p_attribute: 0}]

        metric_orig_train = BinaryLabelDatasetMetric(
            aif_df,  unprivileged_groups=unprivileged_groups, privileged_groups=privileged_groups)

        clsf_metric = ClassificationMetric(
            aif_df, aif_df_labeled, unprivileged_groups=unprivileged_groups, privileged_groups=privileged_groups)

        print('\n AIF 360 ')
        print('\n Statistical parity difference', clsf_metric.statistical_parity_difference())

        print('\n True possitve rate {} \t True negative rate {} '.format(
            clsf_metric.true_positive_rate(), clsf_metric.true_negative_rate()))

        print('\n Desparate impact ', clsf_metric.disparate_impact())
        print('\n Equal opportunity difference ', clsf_metric.equal_opportunity_difference())
        print('\n Average odds difference ', clsf_metric.average_odds_difference())
        print('\n Theil Index ', clsf_metric.theil_index())
        print('\n Binary Confusion Matric ')
        print(clsf_metric.binary_confusion_matrix())
        print('\n ..........................')

        text_expl = MetricTextExplainer(metric_orig_train)

        result_row.append(p_attribute)
        result_row.append(metric_orig_train.mean_difference())
        result_row.append(metric_orig_train.num_positives())
        result_row.append(metric_orig_train.num_negatives())

        # this is to shutup the warning msg from sklearn
        with warnings.catch_warnings():
            warnings.simplefilter('ignore', FutureWarning)
            result_row.append(metric_orig_train.consistency())

        result_row.append(metric_orig_train.disparate_impact())
        result_row.append(metric_orig_train.consistency())
        result_row.append(metric_orig_train.statistical_parity_difference())

        result_rows.append(result_row)

    result_df = pd.DataFrame(result_rows, columns=result_tbl_cols)
    display(result_df)
    # End Aif matrix

# %%
# %%time
# Random Forest Original
runModels(1, 1)
# Out:
# <h2>1.1 Random Forest - original </h2>
# Charn values Original
# 0    95000
# 1     5000
# Name: churn, dtype: int64
# Total data: 100000
#
# Charn values Train
# 0    63606
# 1     3394
# Name: churn, dtype: int64
# Total data: 67000
#
# Charn values Test
# 0    31394
# 1     1606
# Name: churn, dtype: int64
# Total data: 33000
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.96836
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32106
#            1       0.46      0.82      0.59       894
#
#     accuracy                           0.97     33000
#    macro avg       0.73      0.90      0.79     33000
# weighted avg       0.98      0.97      0.97     33000
#
# Creating Learning curve for Random Forest - original
# CPU times: user 2.57 s, sys: 1.29 s, total: 3.86 s
# Wall time: 1min 18s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    20046
# 0    12954
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12644
#       1         19462
# 1     0           310
#       1           584
# # # # # # # # # # #
# [[31237   157]
#  [  869   737]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9201496391303841
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.0052021619381490206
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8214340099107272
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 894.0, 'FP': 0.0, 'TN': 32106.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.005202             894.0   32106.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9929030303030303]          0.821434  [0.9929030303030303]
#
#    Statistical parity dif
# 0               -0.005202
# CPU times: user 1min 11s, sys: 1.44 s, total: 1min 13s
# Wall time: 2min 29s

# %%
# %%time
# Random Forest [Adasyn]
runModels(1, 2)
# Out:
# <h2>1.2 Random Forest - adasyn </h2>
# Charn values Original
# 0    95000
# 1    94412
# Name: churn, dtype: int64
# Total data: 189412
#
# Charn values Train
# 0    63726
# 1    63180
# Name: churn, dtype: int64
# Total data: 126906
#
# Charn values Test
# 0    31274
# 1    31232
# Name: churn, dtype: int64
# Total data: 62506
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9733339836475245
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     31756
#            1       0.97      0.99      0.98     30750
#
#     accuracy                           0.98     62506
#    macro avg       0.98      0.98      0.98     62506
# weighted avg       0.98      0.98      0.98     62506
#
# Creating Learning curve for Random Forest - adasyn
# CPU times: user 1.51 s, sys: 422 ms, total: 1.93 s
# Wall time: 9min 16s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33446
# 0    29060
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12523
#       1         19233
# 1     0         16537
#       1         14213
# # # # # # # # # # #
# [[30951   323]
#  [  805 30427]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9969050603153172
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.1441103488652951
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.33912015254687
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30750.0, 'FP': 0.0, 'TN': 31756.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender          0.14411           30750.0   31756.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8152945317249451]           1.33912  [0.8152945317249451]
#
#    Statistical parity dif
# 0                 0.14411
# CPU times: user 3min 5s, sys: 1min 1s, total: 4min 7s
# Wall time: 12min 17s

# %%
# %%time
# Random Forest [Smote]
runModels(1, 3)
# Out:
# <h2>1.3 Random Forest - smote </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9802736842105263
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     31883
#            1       0.97      0.99      0.98     30817
#
#     accuracy                           0.98     62700
#    macro avg       0.98      0.98      0.98     62700
# weighted avg       0.98      0.98      0.98     62700
#
# Creating Learning curve for Random Forest - smote
# CPU times: user 1.66 s, sys: 363 ms, total: 2.02 s
# Wall time: 10min 38s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33650
# 0    29050
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12585
#       1         19298
# 1     0         16465
#       1         14352
# # # # # # # # # # #
# [[31022   316]
#  [  861 30501]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9965902739395969
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.14027323899716887
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3288875761047054
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30817.0, 'FP': 0.0, 'TN': 31883.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.140273           30817.0   31883.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8449952153110113]          1.328888  [0.8449952153110113]
#
#    Statistical parity dif
# 0                0.140273
# CPU times: user 2min 48s, sys: 3.61 s, total: 2min 52s
# Wall time: 13min 27s

# %%
# %%time
# Random Forest [Rus]
runModels(1, 4)
# Out:
# <h2>1.4 Random Forest - rus </h2>
# Charn values Original
# 0    5000
# 1    5000
# Name: churn, dtype: int64
# Total data: 10000
#
# Charn values Train
# 1    3378
# 0    3322
# Name: churn, dtype: int64
# Total data: 6700
#
# Charn values Test
# 0    1678
# 1    1622
# Name: churn, dtype: int64
# Total data: 3300
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8351999999999998
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84      1675
#            1       0.84      0.84      0.84      1625
#
#     accuracy                           0.84      3300
#    macro avg       0.84      0.84      0.84      3300
# weighted avg       0.84      0.84      0.84      3300
#
# Creating Learning curve for Random Forest - rus
# CPU times: user 1.44 s, sys: 435 ms, total: 1.88 s
# Wall time: 18.6 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    2086
# 0    1214
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0           652
#       1          1023
# 1     0           562
#       1          1063
# # # # # # # # # # #
# [[1416  262]
#  [ 259 1363]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9321396868740163
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.04665527301331068
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.9084450616126377
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 1625.0, 'FP': 0.0, 'TN': 1675.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.046655            1625.0    1675.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7561818181818172]          0.908445  [0.7561818181818172]
#
#    Statistical parity dif
# 0               -0.046655
# CPU times: user 7.4 s, sys: 565 ms, total: 7.96 s
# Wall time: 26.6 s

# %%
# %%time
# Random Forest [Ros]
runModels(1, 5)
# Out:
# <h2>1.5 Random Forest - ros </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9959473684210526
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     30984
#            1       1.00      0.99      0.99     31716
#
#     accuracy                           0.99     62700
#    macro avg       0.99      0.99      0.99     62700
# weighted avg       0.99      0.99      0.99     62700
#
# Creating Learning curve for Random Forest - ros
# CPU times: user 1.76 s, sys: 446 ms, total: 2.2 s
# Wall time: 10min 19s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    39824
# 0    22876
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12318
#       1         18666
# 1     0         10558
#       1         21158
# # # # # # # # # # #
# [[30984   354]
#  [    0 31362]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9998055650659212
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.06975592941167047
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8687040300174702
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 31716.0, 'FP': 0.0, 'TN': 30984.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.069756           31716.0   30984.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9217448165869233]          0.868704  [0.9217448165869233]
#
#    Statistical parity dif
# 0               -0.069756
# CPU times: user 2min 17s, sys: 733 ms, total: 2min 18s
# Wall time: 12min 37s

# %%
# %%time
runModels(2, 1)
# Out:
# <h2>2.1 LightGBM - original </h2>
# Charn values Original
# 0    95000
# 1     5000
# Name: churn, dtype: int64
# Total data: 100000
#
# Charn values Train
# 0    63606
# 1     3394
# Name: churn, dtype: int64
# Total data: 67000
#
# Charn values Test
# 0    31394
# 1     1606
# Name: churn, dtype: int64
# Total data: 33000
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9686
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     31997
#            1       0.47      0.76      0.58      1003
#
#     accuracy                           0.97     33000
#    macro avg       0.73      0.87      0.78     33000
# weighted avg       0.98      0.97      0.97     33000
#
# Creating Learning curve for LightGBM - original
# CPU times: user 2.63 s, sys: 516 ms, total: 3.14 s
# Wall time: 13.2 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    20046
# 0    12954
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12613
#       1         19384
# 1     0           341
#       1           662
# # # # # # # # # # #
# [[31150   244]
#  [  847   759]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9398315178848891
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.006700129304267624
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.7971136072003795
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 1003.0, 'FP': 0.0, 'TN': 31997.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender          -0.0067            1003.0   31997.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9895939393939395]          0.797114  [0.9895939393939395]
#
#    Statistical parity dif
# 0                 -0.0067
# CPU times: user 42.7 s, sys: 758 ms, total: 43.5 s
# Wall time: 19.8 s

# %%
# %%time
runModels(2, 2)
# Out:
# <h2>2.2 LightGBM - adasyn </h2>
# Charn values Original
# 0    95000
# 1    94412
# Name: churn, dtype: int64
# Total data: 189412
#
# Charn values Train
# 0    63726
# 1    63180
# Name: churn, dtype: int64
# Total data: 126906
#
# Charn values Test
# 0    31274
# 1    31232
# Name: churn, dtype: int64
# Total data: 62506
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9715865700163538
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32141
#            1       0.96      0.99      0.98     30365
#
#     accuracy                           0.98     62506
#    macro avg       0.98      0.98      0.98     62506
# weighted avg       0.98      0.98      0.98     62506
#
# Creating Learning curve for LightGBM - adasyn
# CPU times: user 2.47 s, sys: 500 ms, total: 2.97 s
# Wall time: 1min 1s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33446
# 0    29060
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12738
#       1         19403
# 1     0         16322
#       1         14043
# # # # # # # # # # #
# [[31045   229]
#  [ 1096 30136]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9965488845754985
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.14179468304220522
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3377102448928004
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30365.0, 'FP': 0.0, 'TN': 32141.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.141795           30365.0   32141.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8141714395417942]           1.33771  [0.8141714395417942]
#
#    Statistical parity dif
# 0                0.141795
# CPU times: user 2min 48s, sys: 1min 5s, total: 3min 54s
# Wall time: 1min 30s

# %%
# %%time
runModels(2, 3)
# Out:
# <h2>2.3 LightGBM - smote </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9780263157894735
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32170
#            1       0.97      0.99      0.98     30530
#
#     accuracy                           0.98     62700
#    macro avg       0.98      0.98      0.98     62700
# weighted avg       0.98      0.98      0.98     62700
#
# Creating Learning curve for LightGBM - smote
# CPU times: user 2.62 s, sys: 500 ms, total: 3.12 s
# Wall time: 1min 2s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33650
# 0    29050
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12743
#       1         19427
# 1     0         16307
#       1         14223
# # # # # # # # # # #
# [[31104   234]
#  [ 1066 30296]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9964631879008663
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.13866792152690582
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3280725275525824
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30530.0, 'FP': 0.0, 'TN': 32170.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.138668           30530.0   32170.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8441275917065454]          1.328073  [0.8441275917065454]
#
#    Statistical parity dif
# 0                0.138668
# CPU times: user 1min 11s, sys: 3.71 s, total: 1min 15s
# Wall time: 1min 20s

# %%
# %%time
runModels(2, 4)
# Out:
# <h2>2.4 LightGBM - rus </h2>
# Charn values Original
# 0    5000
# 1    5000
# Name: churn, dtype: int64
# Total data: 10000
#
# Charn values Train
# 1    3378
# 0    3322
# Name: churn, dtype: int64
# Total data: 6700
#
# Charn values Test
# 0    1678
# 1    1622
# Name: churn, dtype: int64
# Total data: 3300
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8404999999999999
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1638
#            1       0.85      0.83      0.84      1662
#
#     accuracy                           0.84      3300
#    macro avg       0.84      0.84      0.84      3300
# weighted avg       0.84      0.84      0.84      3300
#
# Creating Learning curve for LightGBM - rus
# CPU times: user 1.6 s, sys: 392 ms, total: 1.99 s
# Wall time: 4.03 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    2086
# 0    1214
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0           653
#       1           985
# 1     0           561
#       1          1101
# # # # # # # # # # #
# [[1395  283]
#  [ 243 1379]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9321575065142728
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.06569567888851857
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8755302578006814
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 1662.0, 'FP': 0.0, 'TN': 1638.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.065696            1662.0    1638.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7570909090909078]           0.87553  [0.7570909090909078]
#
#    Statistical parity dif
# 0               -0.065696
# CPU times: user 18.9 s, sys: 491 ms, total: 19.4 s
# Wall time: 7.36 s

# %%
# %%time
runModels(2, 5)
# Out:
# <h2>2.5 LightGBM - ros </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8958736842105264
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89     29173
#            1       0.93      0.87      0.90     33527
#
#     accuracy                           0.89     62700
#    macro avg       0.89      0.90      0.89     62700
# weighted avg       0.90      0.89      0.89     62700
#
# Creating Learning curve for LightGBM - ros
# CPU times: user 2.55 s, sys: 570 ms, total: 3.12 s
# Wall time: 56.7 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    39824
# 0    22876
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         11897
#       1         17276
# 1     0         10979
#       1         22548
# # # # # # # # # # #
# [[26948  4390]
#  [ 2225 29137]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9640971353728548
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.08625593808771886
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8476558240905927
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 33527.0, 'FP': 0.0, 'TN': 29173.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.086256           33527.0   29173.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8746220095693901]          0.847656  [0.8746220095693901]
#
#    Statistical parity dif
# 0               -0.086256
# CPU times: user 1min 5s, sys: 1.03 s, total: 1min 6s
# Wall time: 1min 13s

# %%
# %%time
runModels(3, 1)
# Out:
# <h2>3.1 Gradient Boosting - original </h2>
# Charn values Original
# 0    95000
# 1     5000
# Name: churn, dtype: int64
# Total data: 100000
#
# Charn values Train
# 0    63606
# 1     3394
# Name: churn, dtype: int64
# Total data: 67000
#
# Charn values Test
# 0    31394
# 1     1606
# Name: churn, dtype: int64
# Total data: 33000
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.96831
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32084
#            1       0.47      0.82      0.60       916
#
#     accuracy                           0.97     33000
#    macro avg       0.73      0.90      0.79     33000
# weighted avg       0.98      0.97      0.97     33000
#
# Creating Learning curve for Gradient Boosting - original
# CPU times: user 2.09 s, sys: 525 ms, total: 2.62 s
# Wall time: 1min 8s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    20046
# 0    12954
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12640
#       1         19444
# 1     0           314
#       1           602
# # # # # # # # # # #
# [[31229   165]
#  [  855   751]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9402003785733423
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.005791311756928496
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8071550905657996
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 916.0, 'FP': 0.0, 'TN': 32084.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.005791             916.0   32084.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9933212121212122]          0.807155  [0.9933212121212122]
#
#    Statistical parity dif
# 0               -0.005791
# CPU times: user 2min 17s, sys: 656 ms, total: 2min 18s
# Wall time: 3min 25s

# %%
# %%time
runModels(3, 2)
# Out:
# <h2>3.2 Gradient Boosting - adasyn </h2>
# Charn values Original
# 0    95000
# 1    94412
# Name: churn, dtype: int64
# Total data: 189412
#
# Charn values Train
# 0    63726
# 1    63180
# Name: churn, dtype: int64
# Total data: 126906
#
# Charn values Test
# 0    31274
# 1    31232
# Name: churn, dtype: int64
# Total data: 62506
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9532930500873317
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     30620
#            1       0.97      0.95      0.96     31886
#
#     accuracy                           0.96     62506
#    macro avg       0.96      0.96      0.96     62506
# weighted avg       0.96      0.96      0.96     62506
#
# Creating Learning curve for Gradient Boosting - adasyn
# CPU times: user 2.06 s, sys: 1.21 s, total: 3.27 s
# Wall time: 15min 43s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33446
# 0    29060
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12199
#       1         18421
# 1     0         16861
#       1         15025
# # # # # # # # # # #
# [[29561  1713]
#  [ 1059 30173]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9918316273061305
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.13098175448470745
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.2915684366386373
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 31886.0, 'FP': 0.0, 'TN': 30620.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.130982           31886.0   30620.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8045115668895638]          1.291568  [0.8045115668895638]
#
#    Statistical parity dif
# 0                0.130982
# CPU times: user 5min 2s, sys: 1min 7s, total: 6min 9s
# Wall time: 20min 40s

# %%
# %%time
runModels(3, 3)
# Out:
# <h2>3.3 Gradient Boosting - smote </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.962078947368421
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96     31771
#            1       0.96      0.97      0.96     30929
#
#     accuracy                           0.96     62700
#    macro avg       0.96      0.96      0.96     62700
# weighted avg       0.96      0.96      0.96     62700
#
# Creating Learning curve for Gradient Boosting - smote
# CPU times: user 2.05 s, sys: 1.39 s, total: 3.44 s
# Wall time: 16min 28s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33650
# 0    29050
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12604
#       1         19167
# 1     0         16446
#       1         14483
# # # # # # # # # # #
# [[30408   930]
#  [ 1363 29999]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9911634269947356
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.13572617790201347
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3153480554030763
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30929.0, 'FP': 0.0, 'TN': 31771.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.135726           30929.0   31771.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8402711323763989]          1.315348  [0.8402711323763989]
#
#    Statistical parity dif
# 0                0.135726
# CPU times: user 4min 28s, sys: 4.6 s, total: 4min 32s
# Wall time: 20min 56s

# %%
# %%time
runModels(3, 4)
# Out:
# <h2>3.4 Gradient Boosting - rus </h2>
# Charn values Original
# 0    5000
# 1    5000
# Name: churn, dtype: int64
# Total data: 10000
#
# Charn values Train
# 1    3378
# 0    3322
# Name: churn, dtype: int64
# Total data: 6700
#
# Charn values Test
# 0    1678
# 1    1622
# Name: churn, dtype: int64
# Total data: 3300
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8411
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85      1615
#            1       0.86      0.83      0.85      1685
#
#     accuracy                           0.85      3300
#    macro avg       0.85      0.85      0.85      3300
# weighted avg       0.85      0.85      0.85      3300
#
# Creating Learning curve for Gradient Boosting - rus
# CPU times: user 1.29 s, sys: 284 ms, total: 1.57 s
# Wall time: 21.9 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    2086
# 0    1214
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0           636
#       1           979
# 1     0           578
#       1          1107
# # # # # # # # # # #
# [[1392  286]
#  [ 223 1399]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9350290405023889
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.05456870230816252
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8971722556324959
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 1685.0, 'FP': 0.0, 'TN': 1615.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.054569            1685.0    1615.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7554545454545447]          0.897172  [0.7554545454545447]
#
#    Statistical parity dif
# 0               -0.054569
# CPU times: user 12.1 s, sys: 406 ms, total: 12.5 s
# Wall time: 34.7 s

# %%
# %%time
runModels(3, 5)
# Out:
# <h2>3.5 Gradient Boosting - ros </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8516999999999999
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     30316
#            1       0.87      0.84      0.86     32384
#
#     accuracy                           0.85     62700
#    macro avg       0.85      0.85      0.85     62700
# weighted avg       0.85      0.85      0.85     62700
#
# Creating Learning curve for Gradient Boosting - ros
# CPU times: user 2.12 s, sys: 470 ms, total: 2.58 s
# Wall time: 16min 43s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    39824
# 0    22876
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12302
#       1         18014
# 1     0         10574
#       1         21810
# # # # # # # # # # #
# [[26228  5110]
#  [ 4088 27274]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.941682021526991
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.08542854339826139
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.8440116317151599
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 32384.0, 'FP': 0.0, 'TN': 30316.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.085429           32384.0   30316.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8736746411483385]          0.844012  [0.8736746411483385]
#
#    Statistical parity dif
# 0               -0.085429
# CPU times: user 4min, sys: 703 ms, total: 4min 1s
# Wall time: 20min 44s

# %%
# %%time
runModels(4, 1)
# Out:
# <h2>4.1 Logistic Reg. - original </h2>
# Charn values Original
# 0    95000
# 1     5000
# Name: churn, dtype: int64
# Total data: 100000
#
# Charn values Train
# 0    63606
# 1     3394
# Name: churn, dtype: int64
# Total data: 67000
#
# Charn values Test
# 0    31394
# 1     1606
# Name: churn, dtype: int64
# Total data: 33000
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9526199999999999
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     32809
#            1       0.09      0.74      0.16       191
#
#     accuracy                           0.95     33000
#    macro avg       0.54      0.85      0.57     33000
# weighted avg       0.99      0.95      0.97     33000
#
# Creating Learning curve for Logistic Reg. - original
# CPU times: user 4.08 s, sys: 1.13 s, total: 5.21 s
# Wall time: 25.3 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    20046
# 0    12954
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12898
#       1         19911
# 1     0            56
#       1           135
# # # # # # # # # # #
# [[31345    49]
#  [ 1464   142]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9085427401591993
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.0024115215874262706
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.6419158389515036
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 191.0, 'FP': 0.0, 'TN': 32809.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.002412             191.0   32809.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9961575757575758]          0.641916  [0.9961575757575758]
#
#    Statistical parity dif
# 0               -0.002412
# CPU times: user 1min 37s, sys: 1min 35s, total: 3min 12s
# Wall time: 41 s

# %%
# %%time
runModels(4, 2)
# Out:
# <h2>4.2 Logistic Reg. - adasyn </h2>
# Charn values Original
# 0    95000
# 1    94412
# Name: churn, dtype: int64
# Total data: 189412
#
# Charn values Train
# 0    63726
# 1    63180
# Name: churn, dtype: int64
# Total data: 126906
#
# Charn values Test
# 0    31274
# 1    31232
# Name: churn, dtype: int64
# Total data: 62506
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8122157108673005
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80     22813
#            1       0.96      0.76      0.85     39693
#
#     accuracy                           0.83     62506
#    macro avg       0.83      0.85      0.83     62506
# weighted avg       0.87      0.83      0.83     62506
#
# Creating Learning curve for Logistic Reg. - adasyn
# CPU times: user 8.67 s, sys: 1.26 s, total: 9.93 s
# Wall time: 5min 12s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33446
# 0    29060
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0          8097
#       1         14716
# 1     0         20963
#       1         18730
# # # # # # # # # # #
# [[21692  9582]
#  [ 1121 30111]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9212715914915051
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.16136240443296157
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.2881434585512457
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 39693.0, 'FP': 0.0, 'TN': 22813.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.161362           39693.0   22813.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7655713051546802]          1.288143  [0.7655713051546802]
#
#    Statistical parity dif
# 0                0.161362
# CPU times: user 4min 14s, sys: 4min 23s, total: 8min 38s
# Wall time: 5min 59s

# %%
# %%time
runModels(4, 3)
# Out:
# <h2>4.3 Logistic Reg. - smote </h2>
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8537736842105265
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83     25509
#            1       0.94      0.79      0.86     37191
#
#     accuracy                           0.84     62700
#    macro avg       0.84      0.86      0.84     62700
# weighted avg       0.86      0.84      0.85     62700
#
# Creating Learning curve for Logistic Reg. - smote
# CPU times: user 8.25 s, sys: 1.43 s, total: 9.68 s
# Wall time: 5min 53s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33650
# 0    29050
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0          9074
#       1         16435
# 1     0         19976
#       1         17215
# # # # # # # # # # #
# [[23547  7791]
#  [ 1962 29400]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9300829752391183
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.17605210056954634
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3441273996029761
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 37191.0, 'FP': 0.0, 'TN': 25509.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.176052           37191.0   25509.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7902807017543689]          1.344127  [0.7902807017543689]
#
#    Statistical parity dif
# 0                0.176052
# CPU times: user 6min 4s, sys: 4min 29s, total: 10min 34s
# Wall time: 6min 44s

# %%
# %%time
runModels(4, 4)
# Out:
# <h2>4.4 Logistic Reg. - rus </h2>
# Charn values Original
# 0    5000
# 1    5000
# Name: churn, dtype: int64
# Total data: 10000
#
# Charn values Train
# 1    3378
# 0    3322
# Name: churn, dtype: int64
# Total data: 6700
#
# Charn values Test
# 0    1678
# 1    1622
# Name: churn, dtype: int64
# Total data: 3300
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.7981
#               precision    recall  f1-score   support
#
#            0       0.66      0.92      0.77      1202
#            1       0.94      0.73      0.82      2098
#
#     accuracy                           0.80      3300
#    macro avg       0.80      0.82      0.79      3300
# weighted avg       0.84      0.80      0.80      3300
#
# Creating Learning curve for Logistic Reg. - rus
# CPU times: user 2.17 s, sys: 1.15 s, total: 3.32 s
# Wall time: 10.9 s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    2086
# 0    1214
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0           460
#       1           742
# 1     0           754
#       1          1344
# # # # # # # # # # #
# [[1107  571]
#  [  95 1527]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.898566566092862
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.023207987351149262
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.9639792696320704
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 2098.0, 'FP': 0.0, 'TN': 1202.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.023208            2098.0    1202.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7446666666666659]          0.963979  [0.7446666666666659]
#
#    Statistical parity dif
# 0               -0.023208
# CPU times: user 9.13 s, sys: 15 s, total: 24.2 s
# Wall time: 14.4 s

# %%
# %%time
runModels(4, 5)
# Out:
# <h2>4.5 Logistic Reg. - ros </h2>
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.7992947368421053
#               precision    recall  f1-score   support
#
#            0       0.66      0.92      0.77     22413
#            1       0.94      0.73      0.83     40287
#
#     accuracy                           0.80     62700
#    macro avg       0.80      0.83      0.80     62700
# weighted avg       0.84      0.80      0.81     62700
#
# Creating Learning curve for Logistic Reg. - ros
# CPU times: user 8.09 s, sys: 1.27 s, total: 9.36 s
# Wall time: 4min 34s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    39824
# 0    22876
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0          8728
#       1         13685
# 1     0         14148
#       1         26139
# # # # # # # # # # #
# [[20637 10701]
#  [ 1776 29586]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.9006780824590849
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.03789823062004383
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.9422602572320048
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 40287.0, 'FP': 0.0, 'TN': 22413.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.037898           40287.0   22413.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8248931419457735]           0.94226  [0.8248931419457735]
#
#    Statistical parity dif
# 0               -0.037898
# CPU times: user 4min 7s, sys: 2min 55s, total: 7min 2s
# Wall time: 5min 12s

# %%
# %%time
runModels(5, 1)
# Out:
# <h2>5.1 XGBClassifier - original </h2>
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [13:36:59] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Charn values Original
# 0    95000
# 1     5000
# Name: churn, dtype: int64
# Total data: 100000
#
# Charn values Train
# 0    63606
# 1     3394
# Name: churn, dtype: int64
# Total data: 67000
#
# Charn values Test
# 0    31394
# 1     1606
# Name: churn, dtype: int64
# Total data: 33000
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9682700000000001
# [13:37:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32030
#            1       0.48      0.80      0.60       970
#
#     accuracy                           0.97     33000
#    macro avg       0.74      0.89      0.79     33000
# weighted avg       0.98      0.97      0.97     33000
#
# Creating Learning curve for XGBClassifier - original
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ...
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# CPU times: user 1.96 s, sys: 303 ms, total: 2.26 s
# Wall time: 1h 22min 43s
#
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    20046
# 0    12954
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12628
#       1         19402
# 1     0           326
#       1           644
# # # # # # # # # # #
# [[31199   195]
#  [  831   775]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ROC AUC Score 0.9379042988836458
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.006960138046550365
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.7833494917994587
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 970.0, 'FP': 0.0, 'TN': 32030.0, 'FN': 0.0}
#
#  ..........................
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         -0.00696             970.0   32030.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.9902121212121213]          0.783349  [0.9902121212121213]
#
#    Statistical parity dif
# 0                -0.00696
# CPU times: user 6min 59s, sys: 846 ms, total: 7min
# Wall time: 1h 23min 13s

# %%
# %%time
runModels(5, 2)
# Out:
# <h2>5.2 XGBClassifier - adasyn </h2>
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:29] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [15:00:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Charn values Original
# 0    95000
# 1    94412
# Name: churn, dtype: int64
# Total data: 189412
#
# Charn values Train
# 0    63726
# 1    63180
# Name: churn, dtype: int64
# Total data: 126906
#
# Charn values Test
# 0    31274
# 1    31232
# Name: churn, dtype: int64
# Total data: 62506
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.971845264734094
# [15:00:47] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     31950
#            1       0.97      0.99      0.98     30556
#
#     accuracy                           0.98     62506
#    macro avg       0.98      0.98      0.98     62506
# weighted avg       0.98      0.98      0.98     62506
#
# Creating Learning curve for XGBClassifier - adasyn
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [13:37:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:39:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:41:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:42:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:44:55] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:46:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:48:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:50:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:52:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:54:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:56:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:58:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:12:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:18:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:20:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:22:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:24:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:26:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:28:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:30:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:32:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:34:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:36:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:38:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:40:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:41:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:43:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:45:47] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:47:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:00:53] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:02:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.[13:37:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:39:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:40:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:42:58] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:44:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:46:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:49:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:01:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:03:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:05:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:07:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:09:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:11:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:17:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:19:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:21:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:23:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:25:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:27:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:29:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:31:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:33:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:35:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:37:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:39:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:52:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:54:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:56:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:00:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:03:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:15:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.[13:37:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:38:59] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:40:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:43:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:56:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:58:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:11:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:17:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:19:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:21:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:23:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:24:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:26:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:28:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:30:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:32:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:34:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:36:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:38:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:40:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:42:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:44:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:46:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:50:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:52:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:54:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:00:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:02:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:04:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:18:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.[13:37:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:39:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:41:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:53:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:55:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:57:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:59:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:01:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:03:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:05:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:07:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:09:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:11:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:17:30] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:19:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:21:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:23:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:25:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:27:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:29:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:31:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:44:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:46:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:50:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:52:36] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:54:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:00:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:02:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:04:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:18:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ...
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ag/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [7], in create_learningcurve(classfier, X, y)
#       1 def create_learningcurve(classfier, X, y):
#       2     # classfier = model
#       3     # print('Process started at {}'.format(datetime.datetime.now()))
#       4     train_sizes_initial = np.linspace(0.01, 1.0, 50)
# ----> 5     train_sizes, train_scores, test_scores = learning_curve(
#       6         classfier, X, y, cv=10, scoring='accuracy',
#       7         n_jobs=-1, train_sizes=train_sizes_initial)
#       8     train_mean = np.mean(train_scores, axis=1)
#       9     train_std = np.std(train_scores, axis=1)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:1553, in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1550     for n_train_samples in train_sizes_abs:
#    1551         train_test_proportions.append((train[:n_train_samples], test))
# -> 1553 results = parallel(
#    1554     delayed(_fit_and_score)(
#    1555         clone(estimator),
#    1556         X,
#    1557         y,
#    1558         scorer,
#    1559         train,
#    1560         test,
#    1561         verbose,
#    1562         parameters=None,
#    1563         fit_params=fit_params,
#    1564         return_train_score=True,
#    1565         error_score=error_score,
#    1566         return_times=return_times,
#    1567     )
#    1568     for train, test in train_test_proportions
#    1569 )
#    1570 results = _aggregate_score_dicts(results)
#    1571 train_scores = results["train_scores"].reshape(-1, n_unique_ticks).T
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:434, in Future.result(self, timeout)
#     431 elif self._state == FINISHED:
#     432     return self.__get_result()
# --> 434 self._condition.wait(timeout)
#     436 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     437     raise CancelledError()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33446
# 0    29060
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12657
#       1         19293
# 1     0         16403
#       1         14153
# # # # # # # # # # #
# [[30959   315]
#  [  991 30241]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ROC AUC Score 0.9965393191758236
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.1412931360137628
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3339002492133336
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30556.0, 'FP': 0.0, 'TN': 31950.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender         0.141293           30556.0   31950.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.8142706300195083]            1.3339  [0.8142706300195083]
#
#    Statistical parity dif
# 0                0.141293
# CPU times: user 13min 35s, sys: 1min 4s, total: 14min 40s
# Wall time: 2h 4min 54s

# %%
# %%time
runModels(5, 3)
# Out:
# <h2>5.3 XGBClassifier - smote </h2>
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:04:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:04:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:04:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:04:59] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:05:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Charn values Original
# 0    95000
# 1    95000
# Name: churn, dtype: int64
# Total data: 190000
#
# Charn values Train
# 0    63662
# 1    63638
# Name: churn, dtype: int64
# Total data: 127300
#
# Charn values Test
# 1    31362
# 0    31338
# Name: churn, dtype: int64
# Total data: 62700
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.9772210526315789
# [17:05:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     32056
#            1       0.97      0.99      0.98     30644
#
#     accuracy                           0.98     62700
#    macro avg       0.98      0.98      0.98     62700
# weighted avg       0.98      0.98      0.98     62700
#
# Creating Learning curve for XGBClassifier - smote
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [7], in create_learningcurve(classfier, X, y)
#       1 def create_learningcurve(classfier, X, y):
#       2     # classfier = model
#       3     # print('Process started at {}'.format(datetime.datetime.now()))
#       4     train_sizes_initial = np.linspace(0.01, 1.0, 50)
# ----> 5     train_sizes, train_scores, test_scores = learning_curve(
#       6         classfier, X, y, cv=10, scoring='accuracy',
#       7         n_jobs=-1, train_sizes=train_sizes_initial)
#       8     train_mean = np.mean(train_scores, axis=1)
#       9     train_std = np.std(train_scores, axis=1)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:1553, in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1550     for n_train_samples in train_sizes_abs:
#    1551         train_test_proportions.append((train[:n_train_samples], test))
# -> 1553 results = parallel(
#    1554     delayed(_fit_and_score)(
#    1555         clone(estimator),
#    1556         X,
#    1557         y,
#    1558         scorer,
#    1559         train,
#    1560         test,
#    1561         verbose,
#    1562         parameters=None,
#    1563         fit_params=fit_params,
#    1564         return_train_score=True,
#    1565         error_score=error_score,
#    1566         return_times=return_times,
#    1567     )
#    1568     for train, test in train_test_proportions
#    1569 )
#    1570 results = _aggregate_score_dicts(results)
#    1571 train_scores = results["train_scores"].reshape(-1, n_unique_ticks).T
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:434, in Future.result(self, timeout)
#     431 elif self._state == FINISHED:
#     432     return self.__get_result()
# --> 434 self._condition.wait(timeout)
#     436 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     437     raise CancelledError()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    33650
# 0    29050
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0         12693
#       1         19363
# 1     0         16357
#       1         14287
# # # # # # # # # # #
# [[31038   300]
#  [ 1018 30344]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ROC AUC Score 0.9964731144149921
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference 0.1384871602734436
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  1.3261771500805892
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 30644.0, 'FP': 0.0, 'TN': 32056.0, 'FN': 0.0}
#
#  ..........................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#     122 with warnings.catch_warnings():
#     123     warnings.simplefilter('ignore', FutureWarning)
# --> 124     result_row.append(metric_orig_train.consistency())
#     126 result_row.append(metric_orig_train.disparate_impact())
#     127 result_row.append(metric_orig_train.consistency())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/aif360/metrics/metric.py:37, in memoize.<locals>.wrapper(*args, **kwargs)
#      35 if result is not sentinal:
#      36     return result
# ---> 37 result = func(*args, **kwargs)
#      38 cache[key] = result
#      39 return result
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/aif360/metrics/binary_label_dataset_metric.py:149, in BinaryLabelDatasetMetric.consistency(self, n_neighbors)
#     147 nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='ball_tree')
#     148 nbrs.fit(X)
# --> 149 _, indices = nbrs.kneighbors(X)
#     151 # compute consistency score
#     152 consistency = 0.0
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py:776, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     774     else:
#     775         parallel_kwargs = {"prefer": "threads"}
# --> 776     chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     777         delayed(_tree_query_parallel_helper)(
#     778             self._tree, X[s], n_neighbors, return_distance
#     779         )
#     780         for s in gen_even_slices(X.shape[0], n_jobs)
#     781     )
#     782 else:
#     783     raise ValueError("internal: _fit_method not recognized")
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py:600, in _tree_query_parallel_helper(tree, *args, **kwargs)
#     594 def _tree_query_parallel_helper(tree, *args, **kwargs):
#     595     """Helper for the Parallel calls in KNeighborsMixin.kneighbors.
#     596
#     597     The Cython method tree.query is not directly picklable by cloudpickle
#     598     under PyPy.
#     599     """
# --> 600     return tree.query(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# %%time
runModels(5, 4)
# Out:
# <h2>5.4 XGBClassifier - rus </h2>
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#      10 X, y = make_sampling(method, X_original, y_original)
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
# ---> 12 score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')
#      14 print('Charn values Original')
#      15 print(y.value_counts())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/sklearn.py:1250, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
#    1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    (...)
#    1247     label_transform=label_transform,
#    1248 )
# -> 1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    1253     self.get_num_boosting_rounds(),
#    1254     evals=evals,
#    1255     early_stopping_rounds=early_stopping_rounds,
#    1256     evals_result=evals_result,
#    1257     obj=obj,
#    1258     feval=feval,
#    1259     verbose_eval=verbose,
#    1260     xgb_model=model,
#    1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#    1265     self.objective = params["objective"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/training.py:188, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     115 def train(params, dtrain, num_boost_round=10, evals=(), obj=None, feval=None,
#     116           maximize=None, early_stopping_rounds=None, evals_result=None,
#     117           verbose_eval=True, xgb_model=None, callbacks=None):
#     118     # pylint: disable=too-many-statements,too-many-branches, attribute-defined-outside-init
#     119     """Train a booster with given parameters.
#     120
#     121     Parameters
#    (...)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#     191                           obj=obj, feval=feval,
#     192                           xgb_model=xgb_model, callbacks=callbacks,
#     193                           verbose_eval=verbose_eval,
#     194                           evals_result=evals_result,
#     195                           maximize=maximize,
#     196                           early_stopping_rounds=early_stopping_rounds)
#     197     return bst
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/training.py:81, in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79 if callbacks.before_iteration(bst, i, dtrain, evals):
#      80     break
# ---> 81 bst.update(dtrain, i, obj)
#      82 if callbacks.after_iteration(bst, i, dtrain, evals):
#      83     break
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/core.py:1680, in Booster.update(self, dtrain, iteration, fobj)
#    1677 self._validate_features(dtrain)
#    1679 if fobj is None:
# -> 1680     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                             ctypes.c_int(iteration),
#    1682                                             dtrain.handle))
#    1683 else:
#    1684     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# %%time
runModels(5, 5)
# Out:
# <h2>5.5 XGBClassifier - ros </h2>
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:29] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# [17:15:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#      10 X, y = make_sampling(method, X_original, y_original)
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
# ---> 12 score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')
#      14 print('Charn values Original')
#      15 print(y.value_counts())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/sklearn.py:1250, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
#    1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    (...)
#    1247     label_transform=label_transform,
#    1248 )
# -> 1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    1253     self.get_num_boosting_rounds(),
#    1254     evals=evals,
#    1255     early_stopping_rounds=early_stopping_rounds,
#    1256     evals_result=evals_result,
#    1257     obj=obj,
#    1258     feval=feval,
#    1259     verbose_eval=verbose,
#    1260     xgb_model=model,
#    1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#    1265     self.objective = params["objective"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/training.py:188, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     115 def train(params, dtrain, num_boost_round=10, evals=(), obj=None, feval=None,
#     116           maximize=None, early_stopping_rounds=None, evals_result=None,
#     117           verbose_eval=True, xgb_model=None, callbacks=None):
#     118     # pylint: disable=too-many-statements,too-many-branches, attribute-defined-outside-init
#     119     """Train a booster with given parameters.
#     120
#     121     Parameters
#    (...)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#     191                           obj=obj, feval=feval,
#     192                           xgb_model=xgb_model, callbacks=callbacks,
#     193                           verbose_eval=verbose_eval,
#     194                           evals_result=evals_result,
#     195                           maximize=maximize,
#     196                           early_stopping_rounds=early_stopping_rounds)
#     197     return bst
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/training.py:81, in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79 if callbacks.before_iteration(bst, i, dtrain, evals):
#      80     break
# ---> 81 bst.update(dtrain, i, obj)
#      82 if callbacks.after_iteration(bst, i, dtrain, evals):
#      83     break
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/xgboost/core.py:1680, in Booster.update(self, dtrain, iteration, fobj)
#    1677 self._validate_features(dtrain)
#    1679 if fobj is None:
# -> 1680     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                             ctypes.c_int(iteration),
#    1682                                             dtrain.handle))
#    1683 else:
#    1684     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# %%time
runModels(6, 1)
# Out:
# <h2>6.1 DecisionTreeClassifier - original </h2>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#      10 X, y = make_sampling(method, X_original, y_original)
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
# ---> 12 score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')
#      14 print('Charn values Original')
#      15 print(y.value_counts())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# %%time
runModels(6, 2)
# Out:
# <h2>6.2 DecisionTreeClassifier - adasyn </h2>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#       4 display(HTML(f'<h2>{model_index}.{method_index} {name} - {method} </h2>'))
#       5 time.sleep(1)
# ----> 7 time.sleep(1)
#       8 method_index += 1
#       9 # display(HTML(f'<h3> {model_index}.{method_index} {method} </h3>'))
#
# KeyboardInterrupt:

# %%
# %%time
runModels(6, 3)
# Out:
# <h2>6.3 DecisionTreeClassifier - smote </h2>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#      10 X, y = make_sampling(method, X_original, y_original)
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
# ---> 12 score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')
#      14 print('Charn values Original')
#      15 print(y.value_counts())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# %%time
runModels(6, 4)
# Out:
# <h2>6.4 DecisionTreeClassifier - rus </h2>
# Charn values Original
# 0    5000
# 1    5000
# Name: churn, dtype: int64
# Total data: 10000
#
# Charn values Train
# 1    3378
# 0    3322
# Name: churn, dtype: int64
# Total data: 6700
#
# Charn values Test
# 0    1678
# 1    1622
# Name: churn, dtype: int64
# Total data: 3300
#
#
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_
# Mean scores : 0.8024000000000001
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      1733
#            1       0.78      0.81      0.80      1567
#
#     accuracy                           0.80      3300
#    macro avg       0.80      0.80      0.80      3300
# weighted avg       0.80      0.80      0.80      3300
#
# Creating Learning curve for DecisionTreeClassifier - rus
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [7], in create_learningcurve(classfier, X, y)
#       1 def create_learningcurve(classfier, X, y):
#       2     # classfier = model
#       3     # print('Process started at {}'.format(datetime.datetime.now()))
#       4     train_sizes_initial = np.linspace(0.01, 1.0, 50)
# ----> 5     train_sizes, train_scores, test_scores = learning_curve(
#       6         classfier, X, y, cv=10, scoring='accuracy',
#       7         n_jobs=-1, train_sizes=train_sizes_initial)
#       8     train_mean = np.mean(train_scores, axis=1)
#       9     train_std = np.std(train_scores, axis=1)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:1553, in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1550     for n_train_samples in train_sizes_abs:
#    1551         train_test_proportions.append((train[:n_train_samples], test))
# -> 1553 results = parallel(
#    1554     delayed(_fit_and_score)(
#    1555         clone(estimator),
#    1556         X,
#    1557         y,
#    1558         scorer,
#    1559         train,
#    1560         test,
#    1561         verbose,
#    1562         parameters=None,
#    1563         fit_params=fit_params,
#    1564         return_train_score=True,
#    1565         error_score=error_score,
#    1566         return_times=return_times,
#    1567     )
#    1568     for train, test in train_test_proportions
#    1569 )
#    1570 results = _aggregate_score_dicts(results)
#    1571 train_scores = results["train_scores"].reshape(-1, n_unique_ticks).T
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:434, in Future.result(self, timeout)
#     431 elif self._state == FINISHED:
#     432     return self.__get_result()
# --> 434 self._condition.wait(timeout)
#     436 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     437     raise CancelledError()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
#  Gender Count in predited value with X_test set
# # # # # # # # # # #
# 1    2086
# 0    1214
# Name: gender, dtype: int64
#
#
#               counter
# churn gender
# 0     0           672
#       1          1061
# 1     0           542
#       1          1025
# # # # # # # # # # #
# [[1379  299]
#  [ 354 1268]]
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# ROC AUC Score 0.8017813026781633
#  *  *  *  *  *  *  *  *  *  *
# [{'gender': 1}]
#
#  AIF 360
#
#  Statistical parity difference -0.04491305494699893
#
#  True possitve rate 1.0 	 True negative rate 1.0
#
#  Desparate impact  0.9085964559810343
#
#  Equal opportunity difference  0.0
#
#  Average odds difference  0.0
#
#  Theil Index  0.0
#
#  Binary Confusion Matric
# {'TP': 1567.0, 'FP': 0.0, 'TN': 1733.0, 'FN': 0.0}
#
#  ..........................
#   Attribute  Mean difference  Positive Outcome  Negative  \
# 0    gender        -0.044913            1567.0    1733.0
#
#             Differences  Disparate impact           Consistency  \
# 0  [0.7456363636363621]          0.908596  [0.7456363636363621]
#
#    Statistical parity dif
# 0               -0.044913
# CPU times: user 1.05 s, sys: 1.17 s, total: 2.22 s
# Wall time: 3.18 s

# %%
# %%time
runModels(6, 5)
# Out:
# <h2>6.5 DecisionTreeClassifier - ros </h2>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# Input In [8], in runModels(model_index, method_index)
#      10 X, y = make_sampling(method, X_original, y_original)
#      11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)
# ---> 12 score = cross_val_score(model, X, y, cv = 10, scoring='accuracy')
#      14 print('Charn values Original')
#      15 print(y.value_counts())
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~/maw/tm_churn/.venv/lib/python3.8/site-packages/sklearn/tree/_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
